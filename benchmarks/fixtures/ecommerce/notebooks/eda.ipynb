# %% [markdown]
# # Quick EDA — orders/users/events
# Just poking at shapes and basic distributions before anyone builds anything.

# %%
import pandas as pd

orders = pd.read_csv('../data/orders.csv')
users = pd.read_csv('../data/users.csv')
events = pd.read_csv('../data/events.csv')
print(orders.shape, users.shape, events.shape)

# %%
print(users['churned'].value_counts(normalize=True))
print(users['plan'].value_counts(normalize=True))
